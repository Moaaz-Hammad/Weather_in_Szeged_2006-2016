# %% [markdown]
# # Weather in Szeged 2006-2016

# %% [markdown]
# ###### link the dataset: https://www.kaggle.com/datasets/budincsevity/szeged-weather

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing Dataset

# %%
weather = pd.read_csv('weatherHistory.csv')
weather.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
weather.info
# Out:
# <bound method DataFrame.info of                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %% [markdown]
# ### Data Cleaning & Pre-processing

# %% [markdown]
# ###### Dealing with Missing Data

# %%
weather.isna().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
weather.drop('Precip Type',axis='columns', inplace=True)

# %%
weather.head()
# Out:
#                   Formatted Date        Summary  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
weather.isna().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# ###### Drop the columns that I don't need

# %%
weather.drop(['Formatted Date', 'Summary', 'Loud Cover', 'Daily Summary'], axis='columns', inplace=True)

# %%
weather.head()
# Out:
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
# 2         9.377778                  9.377778      0.89             3.9284
# 3         8.288889                  5.944444      0.83            14.1036
# 4         8.755556                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)
# 0                   251.0          15.8263               1015.13
# 1                   259.0          15.8263               1015.63
# 2                   204.0          14.9569               1015.94
# 3                   269.0          15.8263               1016.41
# 4                   259.0          15.8263               1016.51

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.figure(figsize = (10,10))
plt.subplot()
plt.subplot(2,3,1)
plt.title('Wind Speed (km/h)')
plt.hist(x = 'Wind Speed (km/h)',bins =20,data = weather)

plt.subplot(2,3,2)
plt.title('Apparent Temperature (C)')
plt.hist(x = 'Apparent Temperature (C)',bins =20,data = weather)

plt.subplot(2,3,3)
plt.title('Humidity')
plt.hist(x = 'Humidity',bins =20,data = weather)

plt.subplot(2,3,4)
plt.title('Wind Bearing (degrees)')
plt.hist(x = 'Wind Bearing (degrees)',bins =100,data = weather)

plt.subplot(2,3,5)
plt.title('Pressure (millibars)')
plt.hist(x = 'Pressure (millibars)',bins =20,data = weather)

plt.subplot(2,3,6)
plt.title('Visibility (km)')
plt.hist(x = 'Visibility (km)',bins =20,data = weather)


plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(weather.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sns.pairplot(weather)
plt.suptitle("Pair Plot of All Columns", y=1.02)
plt.show()

# %% [markdown]
# ### Building Our Model

# %% [markdown]
# Define X and Y

# %%
weather_X = weather.drop('Temperature (C)', axis=1)
weather_y = weather['Temperature (C)']

# %%
weather_X
# Out:
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                      7.388889      0.89            14.1197
# 1                      7.227778      0.86            14.2646
# 2                      9.377778      0.89             3.9284
# 3                      5.944444      0.83            14.1036
# 4                      6.977778      0.83            11.0446
# ...                         ...       ...                ...
# 96448                 26.016667      0.43            10.9963
# 96449                 24.583333      0.48            10.0947
# 96450                 22.038889      0.56             8.9838
# 96451                 21.522222      0.60            10.5294
# 96452                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Pressure (millibars)
# 0                       251.0          15.8263               1015.13
# 1                       259.0          15.8263               1015.63
# ...

# %%
weather_y
# Out:
# 0         9.472222
# 1         9.355556
# 2         9.377778
# 3         8.288889
# 4         8.755556
#            ...
# 96448    26.016667
# 96449    24.583333
# 96450    22.038889
# 96451    21.522222
# 96452    20.438889
# Name: Temperature (C), Length: 96453, dtype: float64

# %% [markdown]
# ###### Train / Test Split Data

# %%
X_train, X_test, y_train, y_test = train_test_split(weather_X,weather_y,test_size=0.2)

# %%
weather.shape
# Out:
# (96453, 7)

# %%
X_test.shape
# Out:
# (19291, 6)

# %%
X_train.shape
# Out:
# (77162, 6)

# %% [markdown]
# ###### Model Training and Predicting

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pre = model.predict(X_test)
pre
# Out:
# array([18.46723745,  3.9682019 , 25.71620289, ..., 13.49955271,
#         6.72560996, 24.33238408])

# %% [markdown]
# ###### Model Evaluation

# %%
# Model Accuracy 
model.score(X_test,y_test )
# Out:
# 0.9899417877965424

# %%
# Calculate R-squared (R^2)
r2 = r2_score(y_test,pre)
r2
# Out:
# 0.9899417877965424

# %%
# Calculate Mean Absolute Error (MAE)
mea = mean_absolute_error(y_test,pre)
mea
# Out:
# 0.7434025433208888
